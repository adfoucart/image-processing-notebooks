# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib notebook
from skimage.io import imread,imshow,imsave

# %%
im = imread('walking.jpg')
plt.figure()
plt.gray()
plt.imshow(im)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from scipy.signal import convolve2d
from skimage.filters import gaussian

gy = np.array([[-1.,-2.,-1.],[0.,0.,0.],[1.,2.,1.]])
gx = gy.T # transpose operator

print(gy)
print(gx)
# Out:
# [[-1. -2. -1.]
#  [ 0.  0.  0.]
#  [ 1.  2.  1.]]
# [[-1.  0.  1.]
#  [-2.  0.  2.]
#  [-1.  0.  1.]]

# %%
Gy = convolve2d(im, gy)
Gx = convolve2d(im, gx)

plt.figure()
plt.subplot(1,2,1)
plt.imshow(np.abs(Gy))
plt.subplot(1,2,2)
plt.imshow(np.abs(Gx))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="848.3333333333334">

# %%
s = np.sqrt(Gy**2+Gx**2)
d = np.arctan2(Gy,Gx)

plt.figure()
plt.subplot(1,2,1)
plt.imshow(s)
plt.subplot(1,2,2)
plt.imshow(d, cmap=plt.cm.viridis)
plt.colorbar()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="912.5">

# %%
from skimage.filters import sobel

plt.figure()
plt.imshow(sobel(im))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="838.3333333333334">

# %%
from skimage.color import rgb2gray

im = rgb2gray(imread('etretat.jpg'))

#br = sobel(im[:,:,0])
#bg = sobel(im[:,:,1])
#bb = sobel(im[:,:,2])

borders = sobel(im)

plt.figure()
plt.subplot(1,2,1)
plt.imshow(im)
plt.subplot(1,2,2)
plt.imshow(borders)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="915">
