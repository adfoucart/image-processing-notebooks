# %%
from skimage.io import imread,imshow,imsave
# %matplotlib notebook
from matplotlib import pyplot as plt

im = imread('walking.jpg')

plt.figure()
imshow(im)
plt.axis('off')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
print(im)
print(im.shape)
# Out:
# [[188 186 190 ..., 196 203 195]
#  [189 187 189 ..., 194 200 190]
#  [189 187 188 ..., 194 200 190]
#  ...,
#  [ 32  34  36 ...,  27  28  28]
#  [ 33  35  38 ...,  24  23  22]
#  [ 37  37  39 ...,  24  21  19]]
# (799, 640)

# %%
h = [(im==v).sum() for v in range(256)]
print(h, len(h))
# Out:
# [11794, 4107, 3936, 3620, 3554, 3318, 3266, 3210, 3188, 3108, 3158, 3047, 2984, 2769, 2799, 2849, 2813, 2867, 2945, 2949, 2953, 2970, 3119, 3200, 3157, 3249, 3292, 3240, 3294, 3181, 3161, 3039, 3023, 2881, 2826, 2738, 2584, 2403, 2298, 2254, 2165, 2097, 1953, 1815, 1734, 1678, 1583, 1470, 1382, 1341, 1305, 1316, 1201, 1298, 1197, 1149, 1191, 1254, 1184, 1139, 1166, 1162, 1175, 1101, 1168, 1102, 1142, 1120, 1089, 1049, 1130, 1047, 1036, 1052, 1097, 1129, 1288, 1240, 1225, 1239, 1316, 1332, 1387, 1388, 1436, 1421, 1362, 1321, 1228, 1232, 1173, 1052, 1111, 1019, 1008, 994, 933, 944, 852, 820, 813, 793, 817, 773, 713, 745, 690, 753, 751, 722, 746, 709, 710, 718, 693, 706, 659, 658, 625, 632, 585, 618, 563, 561, 605, 599, 605, 615, 631, 596, 675, 694, 655, 661, 639, 654, 663, 670, 649, 672, 719, 763, 782, 826, 802, 874, 914, 955, 958, 968, 1047, 1114, 1169, 1215, 1290, 1372, 1412, 1506, 1557, 1598, 1733, 1816, 1903, 2052, 2130, 2383, 2667, 2782, 3016, 3386, 3864, 4226, 4954, 5527, 6212, 6530, 6872, 6918, 6889, 7053, 7021, 7362, 7918, 8245, 8635, 9050, 8602, 8089, 6840, 5834, 4622, 4083, 3516, 3180, 2882, 2746, 2647, 2623, 2592, 2735, 2833, 2878, 2939, 3074, 3133, 3194, 3318, 3479, 3634, 3604, 3653, 3697, 3480, 3118, 2637, 2310, 2049, 1766, 1319, 1084, 905, 739, 650, 598, 546, 455, 412, 359, 335, 263, 213, 184, 129, 114, 86, 74, 66, 52, 32, 30, 30, 18, 15, 21, 14, 10, 15, 5, 13, 5, 4, 3, 12, 8, 9, 44] 256

# %%
plt.figure()
plt.bar(range(256), h)
plt.show()
# Out:
# <img src="data:image/png;base64,...">
