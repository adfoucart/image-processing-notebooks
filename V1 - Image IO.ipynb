# %%
from skimage.io import imread, imshow, imsave

im = imread('gredos.jpg')

# %%
# %matplotlib notebook
from matplotlib import pyplot as plt

plt.figure()
imshow(im)
plt.axis('off')
plt.title('Image title')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
imsave('gredos (copy).jpg', im)
