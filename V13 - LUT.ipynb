# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib notebook

LUT = np.array([4, 3, 2, 1, 7, 6, 5, 0])
for i in range(8):
    print("%d -> %d"%(i,LUT[i]))
    
plt.figure()
plt.plot(range(8), LUT, 'b+-')
plt.show()
# Out:
# 0 -> 4
# 1 -> 3
# 2 -> 2
# 3 -> 1
# 4 -> 7
# 5 -> 6
# 6 -> 5
# 7 -> 0
# <img src="data:image/png;base64,..." width="640">

# %%
from skimage.io import imread,imshow,imsave

im = imread('airplane.jpg')
print(im.shape)

plt.figure()
imshow(im)
plt.show()
# Out:
# (1200, 800)
# <img src="data:image/png;base64,..." width="913.3333333333334">

# %%
LUT = np.array([255-i for i in range(256)])
plt.figure()
plt.plot(range(256), LUT, 'b+-')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="982.5">

# %%
im_out = LUT[im]

plt.figure()
plt.imshow(im_out, cmap=plt.cm.gray)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
LUT = np.arange(256)//4
plt.figure()
plt.plot(range(256), LUT, 'b+-')
plt.show()

plt.figure()
plt.imshow(LUT[im], cmap=plt.cm.gray)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="1020.8333333333334">
