# %%
import numpy as np

# %%
a = np.zeros((3,2))
print("a")
print(a)
b = np.ones((3,2))
print("b")
print(b)
c = np.random.random((3,2))
print("c")
print(c)
d = np.array([[1,2],[3,4],[5,6]])
print("d")
print(d)
# Out:
# a
# [[ 0.  0.]
#  [ 0.  0.]
#  [ 0.  0.]]
# b
# [[ 1.  1.]
#  [ 1.  1.]
#  [ 1.  1.]]
# c
# [[ 0.99690568  0.06448881]
#  [ 0.74110676  0.94908534]
#  [ 0.46858938  0.28700097]]
# d
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
a = np.array([[5,2],[3,4],[1,0]])
b = np.array([[8,-3],[-1,12],[40,20]])
print("a")
print(a)
print("b")
print(b)
print("a+b -> per-element operation")
print(a+b)
print("a+5 -> scalar operation distributed to all elements")
print(a+5)
# Out:
# a
# [[5 2]
#  [3 4]
#  [1 0]]
# b
# [[ 8 -3]
#  [-1 12]
#  [40 20]]
# a+b -> per-element operation
# [[13 -1]
#  [ 2 16]
#  [41 20]]
# a+5 -> scalar operation distributed to all elements
# [[10  7]
#  [ 8  9]
#  [ 6  5]]

# %%
from skimage.io import imread,imshow,imsave
# %matplotlib notebook
from matplotlib import pyplot as plt

im = imread('walking.jpg')
plt.figure()
imshow(im)
plt.figure()
imshow(im+50)
plt.show()
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
print(im[500,200])
window = im[355:560,140:260]

plt.figure()
imshow(window)
plt.show()
# Out:
# 11
# <img src="data:image/png;base64,...">

# %%
im3 = im.copy()
im3[355:560,265:385] = window
plt.figure()
imshow(im3)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
mask = im<30

plt.figure()
imshow(mask)
plt.show()

im4 = im.copy()
im4[mask] = 255

plt.figure()
imshow(im4)
plt.show()
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
print(im)
print("Indexing with scalar coordinates:")
print(im[5,5], im[5,5].shape)
print("Indexing with scalar range:")
print(im[5:10,5:10], im[5:10,5:10].shape)
print("Indexing with boolean mask:")
print(im[mask], im[mask].shape)
# Out:
# [[188 186 190 ..., 196 203 195]
#  [189 187 189 ..., 194 200 190]
#  [189 187 188 ..., 194 200 190]
#  ...,
#  [ 32  34  36 ...,  27  28  28]
#  [ 33  35  38 ...,  24  23  22]
#  [ 37  37  39 ...,  24  21  19]]
# Indexing with scalar coordinates:
# 190 ()
# Indexing with scalar range:
# [[190 192 191 197 193]
#  [189 193 194 196 192]
#  [189 194 196 190 189]
#  [192 193 194 186 190]
#  [197 198 199 192 194]] (5, 5)
# Indexing with boolean mask:
# [28 15 28 ..., 24 21 19] (103936,)

# %%
a = np.array([10,20,30,40])
print("a")
print(a)
b = np.array([[0,1,2,3],[3,2,1,0],[0,3,1,2]])
print("b")
print(b)
print("a[b]")
print(a[b])
# Out:
# a
# [10 20 30 40]
# b
# [[0 1 2 3]
#  [3 2 1 0]
#  [0 3 1 2]]
# a[b]
# [[10 20 30 40]
#  [40 30 20 10]
#  [10 40 20 30]]

# %%
a[2]
# Out:
# 30
