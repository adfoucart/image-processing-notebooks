# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib notebook

from skimage.io import imread,imshow,imsave

im = imread('walking.jpg')
print(im.shape)

plt.figure()
imshow(im)
plt.show()
# Out:
# (799, 640)
# <img src="data:image/png;base64,..." width="640">

# %%
from scipy.signal import convolve2d

# Mean kernel
ksize = 15
kernel = np.ones((ksize,ksize))
kernel /= kernel.sum()

im_out = convolve2d(im, kernel)

plt.figure()
plt.gray()
plt.subplot(1,2,1)
plt.imshow(im[::5,::5])
plt.subplot(1,2,2)
plt.imshow(im_out[::5,::5])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="955.8333333333334">

# %%
from scipy.signal import convolve2d
from skimage.filters import gaussian

# Mean vs Gaussian
im_out2 = gaussian(im, 3)

plt.figure()
plt.gray()
plt.subplot(1,2,1)
plt.imshow(im_out[::5,::5])
plt.subplot(1,2,2)
plt.imshow(im_out2[::5,::5])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="935">

# %%
# Median filter
ksize = 5
im_out3 = np.zeros(im.shape)
for y in range(ksize//2, im.shape[0]-ksize//2):
    for x in range(ksize//2, im.shape[1]-ksize//2):
        im_out3 = np.median(im[y-ksize//2:y+ksize//2+1, x-ksize//2, x+ksize//2+1])

# %%
from skimage.filters.rank import median,mean
from skimage.morphology import square,disk

# Mean vs Median

# %%
# Denoising

im = imread('walking_noisy.jpg')
